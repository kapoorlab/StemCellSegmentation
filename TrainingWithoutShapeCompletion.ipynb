# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from glob import glob
from tqdm import tqdm
from tifffile import imread
from csbdeep.utils import Path, normalize
from csbdeep.utils import axes_dict, plot_some, plot_history
from stardist import fill_label_holes, random_label_cmap
from stardist import Config, StarDist, StarDistData

np.random.seed(42)
lbl_cmap = random_label_cmap()
# Out:
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Using TensorFlow backend.
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
X = sorted(glob('/data/u934/service_imagerie/v_kapoor/HEARD/UNet-training/images/*.tif'))
Y = sorted(glob('/data/u934/service_imagerie/v_kapoor/HEARD/UNet-training/masks/*.tif'))
assert all(Path(x).name==Path(y).name for x,y in zip(X,Y))

# %%
X = list(map(imread,X))
Y = list(map(imread,Y))

# %%
X = [normalize(x,1,99.8) for x in tqdm(X)]
Y = [fill_label_holes(y.astype(int)) for y in tqdm(Y)]
# Out:
# 100%|██████████| 84/84 [00:00<00:00, 329.62it/s]
# 100%|██████████| 84/84 [00:06<00:00, 13.06it/s]

# %%
rng = np.random.RandomState(42)
ind = rng.permutation(len(X))
n_val = int(round(0.15 * len(X)))
ind_train, ind_val = ind[:-n_val], ind[-n_val:]
X_val, Y_val = [X[i] for i in ind_val]  , [Y[i] for i in ind_val]
X_trn, Y_trn = [X[i] for i in ind_train], [Y[i] for i in ind_train] 



print('number of images: %3d' % len(X))
print('- training:       %3d' % len(X_trn))
print('- validation:     %3d' % len(X_val))
print(X[0].shape[0])
# Out:
# number of images:  84
# - training:        71
# - validation:      13
# 512

# %%
i = 9
img, lbl = X[i], Y[i]
plt.figure(figsize=(16,10))
plt.subplot(121); plt.imshow(img,cmap='gray');   plt.axis('off'); plt.title('Raw image')
plt.subplot(122); plt.imshow(lbl,cmap=lbl_cmap); plt.axis('off'); plt.title('GT labels')
None;

# %%
np.random.seed(42)
data = StarDistData(X,Y,batch_size=1,n_rays=32,patch_size=(512,512),shape_completion=False)

# %%
(img,dist_mask), (prob,dist) = data[0]

fig, ax = plt.subplots(2,2, figsize=(12,12))
for a,d,cm,s in zip(ax.flat, [img,prob,dist_mask,dist], ['gray','magma','bone','viridis'],
                    ['Input image','Object probability','Distance mask','Distance (0°)']):
    a.imshow(d[0,...,0],cmap=cm)
    a.set_title(s)
plt.tight_layout()
None;

# %%
print(Config.__doc__)
# Out:
# Configuration for a :class:`StarDist` model.
#
#     Parameters
#     ----------
#     n_rays : int
#         Number of radial directions for the star-convex polygon.
#         Recommended to use a power of 2 (default: 32).
#     n_channel_in : int
#         Number of channels of given input image (default: 1).
#     kwargs : dict
#         Overwrite (or add) configuration attributes (see below).
#
#
#     Attributes
#     ----------
#     unet_n_depth : int
#         Number of U-Net resolution levels (down/up-sampling layers).
#     unet_kernel_size : (int,int)
#         Convolution kernel size for all (U-Net) convolution layers.
#     unet_n_filter_base : int
#         Number of convolution kernels (feature channels) for first U-Net layer.
#         Doubled after each down-sampling layer.
#     net_conv_after_unet : int
#         Number of extra convolution layers after U-Net (0 to disable).
#     train_shape_completion : bool
#         Train model to predict complete shapes for partially visible objects at image boundary.
#     train_completion_crop : int
#         If 'train_shape_completion' is set to True, specify number of pixels to crop at boundary of training patches.
#         Should be chosen based on (largest) object sizes.
#     train_patch_size : (int,int)
#         Size of patches to be cropped from provided training images.
#     train_dist_loss : str
#         Training loss for star-convex polygon distances ('mse' or 'mae').
#     train_epochs : int
#         Number of training epochs.
#     train_steps_per_epoch : int
#         Number of parameter update steps per epoch.
#     train_learning_rate : float
#         Learning rate for training.
#     train_batch_size : int
#         Batch size for training.
#     train_tensorboard : bool
#         Enable TensorBoard for monitoring training progress.
#     train_checkpoint : str
#         Name of checkpoint file for model weights (only best are saved); set to ``None`` to disable.
#     train_reduce_lr : dict
#         Parameter :class:`dict` of ReduceLROnPlateau_ callback; set to ``None`` to disable.
#
#         .. _ReduceLROnPlateau: https://keras.io/callbacks/#reducelronplateau

# %%
conf = Config(train_batch_size=10, train_shape_completion=False, train_patch_size = (512,512), train_epochs = 50, train_steps_per_epoch = 100)
print(conf)
vars(conf)
# Out:
# Config(n_channel_in=1, n_rays=32, net_conv_after_unet=128, net_input_shape=(None, None, 1), train_batch_size=10, train_checkpoint='weights_best.h5', train_completion_crop=32, train_dist_loss='mae', train_epochs=50, train_learning_rate=0.0003, train_patch_size=(512, 512), train_reduce_lr={'patience': 10, 'factor': 0.5}, train_shape_completion=False, train_steps_per_epoch=100, train_tensorboard=True, unet_kernel_size=(3, 3), unet_n_depth=3, unet_n_filter_base=32)
# {'n_channel_in': 1,
#  'n_rays': 32,
#  'net_conv_after_unet': 128,
#  'net_input_shape': (None, None, 1),
#  'train_batch_size': 10,
#  'train_checkpoint': 'weights_best.h5',
#  'train_completion_crop': 32,
#  'train_dist_loss': 'mae',
#  'train_epochs': 50,
#  'train_learning_rate': 0.0003,
#  'train_patch_size': (512, 512),
#  'train_reduce_lr': {'factor': 0.5, 'patience': 10},
#  'train_shape_completion': False,
#  'train_steps_per_epoch': 100,
#  'train_tensorboard': True,
#  'unet_kernel_size': (3, 3),
#  'unet_n_depth': 3,
#  'unet_n_filter_base': 32}

# %%
model = StarDist(conf, name='StemCellWithoutShapeCompletion', basedir='models')
# Out:
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/site-packages/stardist/model.py:272: UserWarning: output path for model already exists, files may be overwritten: /data/u934/service_imagerie/v_kapoor/anaconda2/bin/StarDist/StardistforCurie/models/StemCellWithoutShapeCompletion
#   warnings.warn('output path for model already exists, files may be overwritten: %s' % str(self.logdir.resolve()))

# %%
history = model.train(X_trn,Y_trn,validation_data=(X_val,Y_val))
# Out:
# Epoch 1/50
# 100/100 [==============================] - 235s 2s/step - loss: 5.4692 - prob_loss: 0.4419 - dist_loss: 5.0273 - val_loss: 3.6763 - val_prob_loss: 0.3351 - val_dist_loss: 3.3412
# Epoch 2/50
# 100/100 [==============================] - 213s 2s/step - loss: 3.3861 - prob_loss: 0.3292 - dist_loss: 3.0568 - val_loss: 3.2651 - val_prob_loss: 0.2989 - val_dist_loss: 2.9662
# Epoch 3/50
# 100/100 [==============================] - 216s 2s/step - loss: 3.3168 - prob_loss: 0.3617 - dist_loss: 2.9551 - val_loss: 3.3849 - val_prob_loss: 0.3823 - val_dist_loss: 3.0025
# Epoch 4/50
# 100/100 [==============================] - 217s 2s/step - loss: 3.1856 - prob_loss: 0.2647 - dist_loss: 2.9209 - val_loss: 2.9349 - val_prob_loss: 0.2012 - val_dist_loss: 2.7338
# Epoch 5/50
# 100/100 [==============================] - 215s 2s/step - loss: 2.7315 - prob_loss: 0.2215 - dist_loss: 2.5100 - val_loss: 2.6668 - val_prob_loss: 0.2227 - val_dist_loss: 2.4441
# Epoch 6/50
# 100/100 [==============================] - 217s 2s/step - loss: 2.6049 - prob_loss: 0.2305 - dist_loss: 2.3744 - val_loss: 2.3356 - val_prob_loss: 0.2058 - val_dist_loss: 2.1298
# Epoch 7/50
# 100/100 [==============================] - 216s 2s/step - loss: 2.4354 - prob_loss: 0.3210 - dist_loss: 2.1143 - val_loss: 2.2296 - val_prob_loss: 0.2162 - val_dist_loss: 2.0134
# Epoch 8/50
# 100/100 [==============================] - 215s 2s/step - loss: 2.1724 - prob_loss: 0.2211 - dist_loss: 1.9513 - val_loss: 2.3380 - val_prob_loss: 0.2515 - val_dist_loss: 2.0865
# Epoch 9/50
# 100/100 [==============================] - 222s 2s/step - loss: 2.1041 - prob_loss: 0.2117 - dist_loss: 1.8924 - val_loss: 2.0895 - val_prob_loss: 0.1894 - val_dist_loss: 1.9001
# Epoch 10/50
# 100/100 [==============================] - 218s 2s/step - loss: 2.0154 - prob_loss: 0.2049 - dist_loss: 1.8105 - val_loss: 2.0310 - val_prob_loss: 0.1933 - val_dist_loss: 1.8377
# Epoch 11/50
# 100/100 [==============================] - 219s 2s/step - loss: 2.0129 - prob_loss: 0.2150 - dist_loss: 1.7979 - val_loss: 2.0314 - val_prob_loss: 0.1872 - val_dist_loss: 1.8442
# Epoch 12/50
# 100/100 [==============================] - 218s 2s/step - loss: 2.0382 - prob_loss: 0.2024 - dist_loss: 1.8358 - val_loss: 2.0280 - val_prob_loss: 0.1931 - val_dist_loss: 1.8350
# Epoch 13/50
# 100/100 [==============================] - 220s 2s/step - loss: 1.9184 - prob_loss: 0.1998 - dist_loss: 1.7186 - val_loss: 1.9695 - val_prob_loss: 0.1890 - val_dist_loss: 1.7805
# Epoch 14/50
# 100/100 [==============================] - 222s 2s/step - loss: 1.8341 - prob_loss: 0.1964 - dist_loss: 1.6377 - val_loss: 1.9340 - val_prob_loss: 0.1914 - val_dist_loss: 1.7426
# Epoch 15/50
# 100/100 [==============================] - 235s 2s/step - loss: 1.8135 - prob_loss: 0.1963 - dist_loss: 1.6172 - val_loss: 1.8816 - val_prob_loss: 0.1861 - val_dist_loss: 1.6955
# Epoch 16/50
# 100/100 [==============================] - 222s 2s/step - loss: 1.7980 - prob_loss: 0.1934 - dist_loss: 1.6045 - val_loss: 1.9445 - val_prob_loss: 0.1938 - val_dist_loss: 1.7508
# Epoch 17/50
# 100/100 [==============================] - 220s 2s/step - loss: 1.6967 - prob_loss: 0.1847 - dist_loss: 1.5120 - val_loss: 1.9001 - val_prob_loss: 0.1992 - val_dist_loss: 1.7009
# Epoch 18/50
# 100/100 [==============================] - 216s 2s/step - loss: 1.7646 - prob_loss: 0.1928 - dist_loss: 1.5718 - val_loss: 1.8862 - val_prob_loss: 0.1947 - val_dist_loss: 1.6915
# Epoch 19/50
# 100/100 [==============================] - 217s 2s/step - loss: 1.5859 - prob_loss: 0.1793 - dist_loss: 1.4066 - val_loss: 1.8136 - val_prob_loss: 0.1981 - val_dist_loss: 1.6156
# Epoch 20/50
# 100/100 [==============================] - 219s 2s/step - loss: 1.6051 - prob_loss: 0.1866 - dist_loss: 1.4185 - val_loss: 1.7305 - val_prob_loss: 0.1847 - val_dist_loss: 1.5458
# Epoch 21/50
# 100/100 [==============================] - 220s 2s/step - loss: 1.6451 - prob_loss: 0.1940 - dist_loss: 1.4511 - val_loss: 1.7606 - val_prob_loss: 0.1886 - val_dist_loss: 1.5721
# Epoch 22/50
# 100/100 [==============================] - 218s 2s/step - loss: 1.5622 - prob_loss: 0.1907 - dist_loss: 1.3714 - val_loss: 1.7115 - val_prob_loss: 0.1884 - val_dist_loss: 1.5231
# Epoch 23/50
# 100/100 [==============================] - 220s 2s/step - loss: 1.5894 - prob_loss: 0.1886 - dist_loss: 1.4007 - val_loss: 1.6867 - val_prob_loss: 0.1892 - val_dist_loss: 1.4975
# Epoch 24/50
# 100/100 [==============================] - 217s 2s/step - loss: 1.5832 - prob_loss: 0.2063 - dist_loss: 1.3769 - val_loss: 1.6694 - val_prob_loss: 0.1930 - val_dist_loss: 1.4763
# Epoch 25/50
# 100/100 [==============================] - 214s 2s/step - loss: 1.4712 - prob_loss: 0.1856 - dist_loss: 1.2857 - val_loss: 1.5796 - val_prob_loss: 0.1828 - val_dist_loss: 1.3968
# Epoch 26/50
# 100/100 [==============================] - 214s 2s/step - loss: 1.4357 - prob_loss: 0.1823 - dist_loss: 1.2533 - val_loss: 1.5984 - val_prob_loss: 0.1859 - val_dist_loss: 1.4125
# Epoch 27/50
# 100/100 [==============================] - 209s 2s/step - loss: 1.4096 - prob_loss: 0.1825 - dist_loss: 1.2272 - val_loss: 1.6848 - val_prob_loss: 0.2020 - val_dist_loss: 1.4828
# Epoch 28/50
# 100/100 [==============================] - 211s 2s/step - loss: 1.3351 - prob_loss: 0.1808 - dist_loss: 1.1543 - val_loss: 1.5404 - val_prob_loss: 0.1863 - val_dist_loss: 1.3541
# Epoch 29/50
# 100/100 [==============================] - 212s 2s/step - loss: 1.3080 - prob_loss: 0.1794 - dist_loss: 1.1285 - val_loss: 1.5223 - val_prob_loss: 0.1821 - val_dist_loss: 1.3403
# Epoch 30/50
# 100/100 [==============================] - 219s 2s/step - loss: 1.3372 - prob_loss: 0.1771 - dist_loss: 1.1601 - val_loss: 1.5454 - val_prob_loss: 0.1834 - val_dist_loss: 1.3620
# Epoch 31/50
# 100/100 [==============================] - 211s 2s/step - loss: 1.2780 - prob_loss: 0.1792 - dist_loss: 1.0989 - val_loss: 1.5535 - val_prob_loss: 0.1841 - val_dist_loss: 1.3695
# Epoch 32/50
# 100/100 [==============================] - 213s 2s/step - loss: 1.2928 - prob_loss: 0.1759 - dist_loss: 1.1169 - val_loss: 1.5129 - val_prob_loss: 0.1848 - val_dist_loss: 1.3281
# Epoch 33/50
# 100/100 [==============================] - 212s 2s/step - loss: 1.2382 - prob_loss: 0.1749 - dist_loss: 1.0633 - val_loss: 1.5100 - val_prob_loss: 0.1854 - val_dist_loss: 1.3246
# Epoch 34/50
# 100/100 [==============================] - 214s 2s/step - loss: 1.2288 - prob_loss: 0.1771 - dist_loss: 1.0518 - val_loss: 1.4991 - val_prob_loss: 0.1826 - val_dist_loss: 1.3165
# Epoch 35/50
# 100/100 [==============================] - 206s 2s/step - loss: 1.2307 - prob_loss: 0.1719 - dist_loss: 1.0588 - val_loss: 1.5941 - val_prob_loss: 0.1851 - val_dist_loss: 1.4089
# Epoch 36/50
# 100/100 [==============================] - 213s 2s/step - loss: 1.1956 - prob_loss: 0.1739 - dist_loss: 1.0217 - val_loss: 1.4511 - val_prob_loss: 0.1815 - val_dist_loss: 1.2696
# Epoch 37/50
# 100/100 [==============================] - 208s 2s/step - loss: 1.2312 - prob_loss: 0.1745 - dist_loss: 1.0566 - val_loss: 1.5647 - val_prob_loss: 0.1836 - val_dist_loss: 1.3810
# Epoch 38/50
# 100/100 [==============================] - 207s 2s/step - loss: 1.3015 - prob_loss: 0.1764 - dist_loss: 1.1251 - val_loss: 1.4787 - val_prob_loss: 0.1853 - val_dist_loss: 1.2934
# Epoch 39/50
# 100/100 [==============================] - 212s 2s/step - loss: 1.1662 - prob_loss: 0.1729 - dist_loss: 0.9933 - val_loss: 1.4305 - val_prob_loss: 0.1824 - val_dist_loss: 1.2481
# Epoch 40/50
# 100/100 [==============================] - 213s 2s/step - loss: 1.1522 - prob_loss: 0.1715 - dist_loss: 0.9808 - val_loss: 1.4777 - val_prob_loss: 0.1822 - val_dist_loss: 1.2955
# Epoch 41/50
# 100/100 [==============================] - 223s 2s/step - loss: 1.1354 - prob_loss: 0.1693 - dist_loss: 0.9661 - val_loss: 1.4598 - val_prob_loss: 0.1916 - val_dist_loss: 1.2682
# Epoch 42/50
# 100/100 [==============================] - 217s 2s/step - loss: 1.1718 - prob_loss: 0.1755 - dist_loss: 0.9963 - val_loss: 1.4288 - val_prob_loss: 0.1819 - val_dist_loss: 1.2469
# Epoch 43/50
# 100/100 [==============================] - 213s 2s/step - loss: 1.1506 - prob_loss: 0.1751 - dist_loss: 0.9755 - val_loss: 1.4373 - val_prob_loss: 0.1827 - val_dist_loss: 1.2546
# Epoch 44/50
# 100/100 [==============================] - 210s 2s/step - loss: 1.1073 - prob_loss: 0.1708 - dist_loss: 0.9365 - val_loss: 1.4287 - val_prob_loss: 0.1991 - val_dist_loss: 1.2295
# Epoch 45/50
# 100/100 [==============================] - 211s 2s/step - loss: 1.1136 - prob_loss: 0.1764 - dist_loss: 0.9371 - val_loss: 1.4186 - val_prob_loss: 0.1875 - val_dist_loss: 1.2311
# Epoch 46/50
# 100/100 [==============================] - 206s 2s/step - loss: 1.0552 - prob_loss: 0.1687 - dist_loss: 0.8865 - val_loss: 1.4293 - val_prob_loss: 0.1822 - val_dist_loss: 1.2471
# Epoch 47/50
# 100/100 [==============================] - 214s 2s/step - loss: 1.0582 - prob_loss: 0.1707 - dist_loss: 0.8875 - val_loss: 1.4025 - val_prob_loss: 0.1826 - val_dist_loss: 1.2198
# Epoch 48/50
# 100/100 [==============================] - 221s 2s/step - loss: 1.0381 - prob_loss: 0.1669 - dist_loss: 0.8712 - val_loss: 1.3929 - val_prob_loss: 0.1833 - val_dist_loss: 1.2096
# Epoch 49/50
# 100/100 [==============================] - 210s 2s/step - loss: 1.0467 - prob_loss: 0.1678 - dist_loss: 0.8789 - val_loss: 1.4084 - val_prob_loss: 0.1799 - val_dist_loss: 1.2285
# Epoch 50/50
# 100/100 [==============================] - 212s 2s/step - loss: 1.0917 - prob_loss: 0.1673 - dist_loss: 0.9245 - val_loss: 1.3924 - val_prob_loss: 0.1852 - val_dist_loss: 1.2072

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss'],['prob_loss','val_prob_loss','dist_loss','val_dist_loss']);
# Out:
# ['dist_loss', 'loss', 'lr', 'prob_loss', 'val_dist_loss', 'val_loss', 'val_prob_loss']
